# %% [markdown]
# # CIAO AO Explanation and Validation
#
# In this notebook we explain and validate several aspects of CIAO's closed-loop operation. We start by validating the loop, by comparing CIAO's calculations with explicit calculations. Second, we validate CIAO's poke matrix methods by explicitly computing a poke matrix. Finally, we explain and validate the wavefront and residual error calculations.

# %% [markdown]
# ## Explaining and validating the AO loop
#
# Let's start by importing the CIAO modules and config files, as well as the scientific stack. Then we run the simulation check that is executed at the top of every CIAO script.

# %%
import sys,os
from sys import exit
import ciao_config as ccfg
import ciao
from matplotlib import pyplot as plt
import numpy as np
# Out:
# No module named pypylon
# No module named ximea
# [Errno 17] File exists: '.gui_settings'

# %%
if ccfg.simulate:
    sim = ciao.simulator.Simulator()
    cam = sim
    mirror = cam
else:
    cam = ciao.cameras.get_camera()
    mirror = ciao.mirrors.Mirror()
    
sensor = ciao.sensors.Sensor(cam)

if ccfg.simulate:
    # required to remove tip/tilt in simulated image
    sensor.record_reference()
# Out:
# Loading cached actuator basis set...
# Loading cached zernike basis set...
# recording reference
# sensor paused
# measurement 1 of 10 Sensor sense method
# start -> cam.get_image: 27.387 ms
# cam.get_image -> image stats: 0.159 ms
# image stats -> estimate background: 0.138 ms
# estimate background -> centroid: 0.337 ms
# centroid -> reconstruct wavefront: 0.161 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 2 of 10 Sensor sense method
# start -> cam.get_image: 27.419 ms
# cam.get_image -> image stats: 0.165 ms
# image stats -> estimate background: 0.134 ms
# estimate background -> centroid: 0.342 ms
# centroid -> reconstruct wavefront: 0.157 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 3 of 10 Sensor sense method
# start -> cam.get_image: 29.373 ms
# cam.get_image -> image stats: 0.199 ms
# image stats -> estimate background: 0.173 ms
# estimate background -> centroid: 0.466 ms
# centroid -> reconstruct wavefront: 0.192 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 4 of 10 Sensor sense method
# start -> cam.get_image: 29.622 ms
# cam.get_image -> image stats: 0.186 ms
# image stats -> estimate background: 0.161 ms
# estimate background -> centroid: 0.431 ms
# centroid -> reconstruct wavefront: 0.194 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 5 of 10 Sensor sense method
# start -> cam.get_image: 30.762 ms
# cam.get_image -> image stats: 0.185 ms
# image stats -> estimate background: 0.155 ms
# estimate background -> centroid: 0.414 ms
# centroid -> reconstruct wavefront: 0.189 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 6 of 10 Sensor sense method
# start -> cam.get_image: 30.324 ms
# cam.get_image -> image stats: 0.179 ms
# image stats -> estimate background: 0.152 ms
# estimate background -> centroid: 0.413 ms
# centroid -> reconstruct wavefront: 0.184 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 7 of 10 Sensor sense method
# start -> cam.get_image: 29.943 ms
# cam.get_image -> image stats: 0.176 ms
# image stats -> estimate background: 0.149 ms
# estimate background -> centroid: 0.403 ms
# centroid -> reconstruct wavefront: 0.179 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 8 of 10 Sensor sense method
# start -> cam.get_image: 29.681 ms
# cam.get_image -> image stats: 0.172 ms
# image stats -> estimate background: 0.146 ms
# estimate background -> centroid: 0.394 ms
# centroid -> reconstruct wavefront: 0.175 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 9 of 10 Sensor sense method
# start -> cam.get_image: 29.548 ms
# cam.get_image -> image stats: 0.171 ms
# image stats -> estimate background: 0.144 ms
# estimate background -> centroid: 0.389 ms
# centroid -> reconstruct wavefront: 0.172 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# measurement 10 of 10 Sensor sense method
# start -> cam.get_image: 29.625 ms
# cam.get_image -> image stats: 0.170 ms
# image stats -> estimate background: 0.145 ms
# estimate background -> centroid: 0.384 ms
# centroid -> reconstruct wavefront: 0.171 ms
# reconstruct wavefront -> end sense: 0.001 ms
#
# ...done
# reference coordinate error 1.897e-14 px RMS
# sensor unpaused

# %%
plt.figure(dpi=200)
plt.imshow(cam.get_image())
plt.colorbar()
plt.autoscale(False)
for y1,y2,x1,x2 in zip(sensor.search_boxes.y1,
                       sensor.search_boxes.y2,
                       sensor.search_boxes.x1,
                       sensor.search_boxes.x2):
    plt.plot([x1,x2-1,x2-1,x1,x1],[y1,y1,y2-1,y2-1,y1],'y-',linewidth=.5)

# %%
sensor.sense()
# Out:
# Sensor sense method
# start -> cam.get_image: 29.766 ms
# cam.get_image -> image stats: 0.171 ms
# image stats -> estimate background: 0.143 ms
# estimate background -> centroid: 0.379 ms
# centroid -> reconstruct wavefront: 0.170 ms
# reconstruct wavefront -> end sense: 0.001 ms

# %% [markdown]
# ## Centroiding

# %% [markdown]
# Let's calculate the center of mass of the 20th lenslet, making sure we follow the same approach specified in ciao_config.py.

# %%
n_iterations = ccfg.centroiding_iterations
half_width= ccfg.search_box_half_width
iterative_step = ccfg.iterative_centroiding_step

# an explicit centroiding function
def centroid(spots,x_float,y_float,hw,n_iterations):
    x,y = int(round(x_float)),int(round(y_float))
        
    x1 = x - hw
    x2 = x + hw
    y1 = y - hw
    y2 = y + hw
    
    # first, survey edges to estimate background
    intensity = 0.0
    counter = 0.0
    
    for x in range(x1,x2+1):
        print spots[y1,x],spots[y2,x]
        intensity = intensity + float(spots[y1,x]) + float(spots[y2,x])
        counter = counter + 2.0
    for y in range(y1,y2+1):
        intensity = intensity + float(spots[y,x1]) + float(spots[y,x2])
        counter = counter + 2.0

    background = intensity/counter
    print spots.max(),spots.min()
    print intensity,counter,background
    return
    

    for k in range(n_iterations):
            pass
        

    #plt.subplot(1,2,1)
    plt.imshow(spots,cmap='gray')
    plt.xlim([x1,x2-1])
    plt.ylim([y2-1,y1])
    plt.autoscale(False)
    plt.plot(x_float,y_float,'r.')
    
    #plt.subplot(1,2,2)
    #plt.imshow(arr)
    
idx=5
x_float = sensor.search_boxes.x[idx]
y_float = sensor.search_boxes.y[idx]

centroid(sensor.cam.spots,x_float,y_float,half_width,n_iterations)
# Out:
# 0.00408454879429
# 0.00801213293518
# 0.0117331527565
# 0.0152029847716
# 0.0183769124334
# 0.0212124755178
# 0.0236715241815
# 0.0257214680465
# 0.0273363972295
# 0.0284988835786
# 0.0292042984319
# 0.6908409808533399 1.4437079245194268e-06
# 0.0586222976642 44.0 0.00133232494691
